# %% [markdown]
# Using roulette wheel selection, what is the smallest population size and number of generations to find a perfect solution with an individual size of 50?  Give your answer regarding individuals processed

# %% [markdown]
# Using roulette wheel selection, the smallest population size that found a perfect solution was 121, with 71 generations needed, resulting in 8591 individuals processed. The population range was from 50-200 and the max number of generation was 5000

# %% [markdown]
#    # GA applied to OneMax

# %% [markdown]
# This notebook implements a simple GA in a fairly lowlevel way. In later examples we'll use more highlevel operators, but it is a very valuable exercise to ensure you understand what this code is actually doing. Make sure you understand the processes below before moving to the more high-level toolboxes!

# %% [markdown]
# Install DEAP. Note that if you are running this on your own computer you might not need to do this. In fact, it is better practice to install it so that it is always available, but when running on Colab, we do need this.

# %%
# !pip install deap
# Out:
# Requirement already satisfied: deap in /usr/local/lib/python3.12/dist-packages (1.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from deap) (2.0.2)

# %% [markdown]
# Import the DEAP tools and useful libraries (random and matplotlib).

# %%
from deap import base
from deap import creator
from deap import tools

import random

import matplotlib.pyplot as plt

# %% [markdown]
# Set our Genetic Algorithm parameters

# %%
# Genetic Algorithm constants:
P_CROSSOVER = 0.7  # probability for crossover
P_MUTATION = 0.01   # probability for mutating an individual
MAX_GENERATIONS = 5000

# %% [markdown]
# Set any problem-specific constants here. In this case we need to know how long the string is.

# %%
ONE_MAX_LENGTH = 50  # length of bit string to be optimized

# %% [markdown]
# Set the random seed. This is important so that we can reproduce runs later on.

# %%
RANDOM_SEED = 42
random.seed(RANDOM_SEED)

# %% [markdown]
# Create our toolbox. Note that we can pull in a bunch of predefined operators to tailor our Evolutionary Algorithm, which, of course, in this case is a GA. Notice that it is possible to create our **own** operators and functions to use, which is what we do with our **oneMaxFitness** function below.

# %%
toolbox = base.Toolbox()

# create an operator that randomly returns 0 or 1:
toolbox.register("zeroOrOne", random.randint, 0, 1)

# define a single objective, maximizing fitness strategy:
creator.create("FitnessMax", base.Fitness, weights=(1.0,))

# create the Individual class based on list:
creator.create("Individual", list, fitness=creator.FitnessMax)
#creator.create("Individual", array.array, typecode='b', fitness=creator.FitnessMax)

# create the individual operator to fill up an Individual instance:
toolbox.register("individualCreator", tools.initRepeat, creator.Individual, toolbox.zeroOrOne, ONE_MAX_LENGTH)

# create the population operator to generate a list of individuals:
toolbox.register("populationCreator", tools.initRepeat, list, toolbox.individualCreator)


# fitness calculation:
# compute the number of '1's in the individual
def oneMaxFitness(individual):
    return sum(individual),  # return a tuple


toolbox.register("evaluate", oneMaxFitness)

# genetic operators:

# Tournament selection with tournament size of 3:
toolbox.register("select", tools.selRoulette)

# Single-point crossover:
toolbox.register("mate", tools.cxOnePoint)

# Flip-bit mutation:
# indpb: Independent probability for each attribute to be flipped
toolbox.register("mutate", tools.mutFlipBit, indpb=1.0/ONE_MAX_LENGTH)

# %% [markdown]
# Here is the main GA loop. We will iterate through it up to the MAX_GENERATIONS parameter and then print out our best individual.

# %%
# Run GA for a given population size
 # set a high max to ensure solution is found

def loop(pop_size):
    random.seed(RANDOM_SEED)
    population = toolbox.populationCreator(n=pop_size)
    maxFitnessValues = []
    meanFitnessValues = []

    # calculate fitness tuple for each individual in the population:
    fitnessValues = list(map(toolbox.evaluate, population))
    for individual, fitnessValue in zip(population, fitnessValues):
      individual.fitness.values = fitnessValue

    for generationCounter in range(1, MAX_GENERATIONS + 1):
        # Selection
        offspring = toolbox.select(population, len(population))
        offspring = list(map(toolbox.clone, offspring))

        # Crossover
        for child1, child2 in zip(offspring[::2], offspring[1::2]):
            if random.random() < P_CROSSOVER:
                toolbox.mate(child1, child2)
                del child1.fitness.values
                del child2.fitness.values

        # Mutation
        for mutant in offspring:
            if random.random() < P_MUTATION:
                toolbox.mutate(mutant)
                del mutant.fitness.values

         # calculate fitness for the individuals with no previous calculated fitness value:
        freshIndividuals = [ind for ind in offspring if not ind.fitness.valid]
        freshFitnessValues = list(map(toolbox.evaluate, freshIndividuals))
        for individual, fitnessValue in zip(freshIndividuals, freshFitnessValues):
            individual.fitness.values = fitnessValue

        # Replace population
        population[:] = offspring

        # Check if perfect solution found
        fitnessValues = [ind.fitness.values[0] for ind in population]
        maxFitnessValues.append(max(fitnessValues))
        meanFitnessValues.append(sum(fitnessValues)/len(population))
        if max(fitnessValues) == ONE_MAX_LENGTH:
            individuals_processed = pop_size * generationCounter
            return generationCounter, individuals_processed, maxFitnessValues, meanFitnessValues

    # If not found after MAX_GENERATIONS
    return None, None, None, None

# Search for the population size d
result = None
min_individuals = float('inf')

for psize in range(50, 201):  # populations from 10 to 200
    generations_needed, individuals_processed, maxFit, meanFit = loop(psize)
    if generations_needed is not None:
        if individuals_processed < min_individuals:
            min_individuals = individuals_processed
            result = (psize, generations_needed, individuals_processed, maxFit, meanFit)
        print(f"Pop {psize}  Perfect solution in {generations_needed} generations, {individuals_processed} individuals processed")

if result:
    print("\n Final configuration:")
    print(f"Smallest population size : {result[0]}")
    print(f"smallest Generation size: {result[1]}")
    print(f"Individuals processed = {result[2]}")
else:
    print("Could not find a perfect solution in given population range")
# Out:
# Pop 60  Perfect solution in 4471 generations, 268260 individuals processed
# Pop 61  Perfect solution in 2875 generations, 175375 individuals processed
# Pop 62  Perfect solution in 1742 generations, 108004 individuals processed
# Pop 64  Perfect solution in 2820 generations, 180480 individuals processed
# Pop 67  Perfect solution in 2996 generations, 200732 individuals processed
# Pop 70  Perfect solution in 1420 generations, 99400 individuals processed
# Pop 71  Perfect solution in 2683 generations, 190493 individuals processed
# Pop 73  Perfect solution in 2444 generations, 178412 individuals processed
# Pop 74  Perfect solution in 3231 generations, 239094 individuals processed
# Pop 76  Perfect solution in 3226 generations, 245176 individuals processed
# Pop 77  Perfect solution in 2297 generations, 176869 individuals processed
# Pop 78  Perfect solution in 2744 generations, 214032 individuals processed
# Pop 79  Perfect solution in 2905 generations, 229495 individuals processed
# Pop 82  Perfect solution in 2942 generations, 241244 individuals processed
# Pop 83  Perfect solution in 2763 generations, 229329 individuals processed
# Pop 84  Perfect solution in 2621 generations, 220164 individuals processed
# Pop 85  Perfect solution in 1357 generations, 115345 individuals processed
# Pop 86  Perfect solution in 2007 generations, 172602 individuals processed
# Pop 87  Perfect solution in 2136 generations, 185832 individuals processed
# Pop 88  Perfect solution in 1645 generations, 144760 individuals processed
# Pop 90  Perfect solution in 1962 generations, 176580 individuals processed
# Pop 91  Perfect solution in 1996 generations, 181636 individuals processed
# Pop 92  Perfect solution in 1971 generations, 181332 individuals processed
# Pop 93  Perfect solution in 1878 generations, 174654 individuals processed
# Pop 94  Perfect solution in 497 generations, 46718 individuals processed
# Pop 95  Perfect solution in 736 generations, 69920 individuals processed
# Pop 96  Perfect solution in 1590 generations, 152640 individuals processed
# Pop 97  Perfect solution in 1183 generations, 114751 individuals processed
# Pop 98  Perfect solution in 2860 generations, 280280 individuals processed
# Pop 99  Perfect solution in 2333 generations, 230967 individuals processed
# Pop 100  Perfect solution in 1284 generations, 128400 individuals processed
# Pop 101  Perfect solution in 1677 generations, 169377 individuals processed
# Pop 102  Perfect solution in 1635 generations, 166770 individuals processed
# Pop 103  Perfect solution in 2939 generations, 302717 individuals processed
# Pop 104  Perfect solution in 1513 generations, 157352 individuals processed
# Pop 105  Perfect solution in 2993 generations, 314265 individuals processed
# Pop 106  Perfect solution in 939 generations, 99534 individuals processed
# Pop 107  Perfect solution in 1333 generations, 142631 individuals processed
# Pop 108  Perfect solution in 1330 generations, 143640 individuals processed
# Pop 109  Perfect solution in 253 generations, 27577 individuals processed
# Pop 110  Perfect solution in 1000 generations, 110000 individuals processed
# Pop 111  Perfect solution in 2102 generations, 233322 individuals processed
# Pop 112  Perfect solution in 3913 generations, 438256 individuals processed
# Pop 113  Perfect solution in 2605 generations, 294365 individuals processed
# Pop 114  Perfect solution in 2218 generations, 252852 individuals processed
# Pop 115  Perfect solution in 2532 generations, 291180 individuals processed
# Pop 116  Perfect solution in 2103 generations, 243948 individuals processed
# Pop 117  Perfect solution in 1104 generations, 129168 individuals processed
# Pop 118  Perfect solution in 2053 generations, 242254 individuals processed
# Pop 119  Perfect solution in 1978 generations, 235382 individuals processed
# Pop 120  Perfect solution in 1395 generations, 167400 individuals processed
# Pop 121  Perfect solution in 71 generations, 8591 individuals processed
# Pop 122  Perfect solution in 832 generations, 101504 individuals processed
# Pop 123  Perfect solution in 2901 generations, 356823 individuals processed
# Pop 124  Perfect solution in 1448 generations, 179552 individuals processed
# Pop 125  Perfect solution in 1305 generations, 163125 individuals processed
# Pop 126  Perfect solution in 770 generations, 97020 individuals processed
# Pop 127  Perfect solution in 1839 generations, 233553 individuals processed
# Pop 128  Perfect solution in 1038 generations, 132864 individuals processed
# Pop 129  Perfect solution in 320 generations, 41280 individuals processed
# Pop 130  Perfect solution in 265 generations, 34450 individuals processed
# Pop 131  Perfect solution in 376 generations, 49256 individuals processed
# Pop 132  Perfect solution in 2277 generations, 300564 individuals processed
# Pop 133  Perfect solution in 1183 generations, 157339 individuals processed
# Pop 134  Perfect solution in 233 generations, 31222 individuals processed
# Pop 135  Perfect solution in 1417 generations, 191295 individuals processed
# Pop 136  Perfect solution in 726 generations, 98736 individuals processed
# Pop 137  Perfect solution in 2498 generations, 342226 individuals processed
# Pop 138  Perfect solution in 295 generations, 40710 individuals processed
# Pop 139  Perfect solution in 326 generations, 45314 individuals processed
# Pop 140  Perfect solution in 713 generations, 99820 individuals processed
# Pop 141  Perfect solution in 985 generations, 138885 individuals processed
# Pop 142  Perfect solution in 141 generations, 20022 individuals processed
# Pop 143  Perfect solution in 1506 generations, 215358 individuals processed
# Pop 144  Perfect solution in 145 generations, 20880 individuals processed
# Pop 145  Perfect solution in 118 generations, 17110 individuals processed
# Pop 146  Perfect solution in 178 generations, 25988 individuals processed
# Pop 147  Perfect solution in 1277 generations, 187719 individuals processed
# Pop 148  Perfect solution in 981 generations, 145188 individuals processed
# Pop 149  Perfect solution in 429 generations, 63921 individuals processed
# Pop 150  Perfect solution in 135 generations, 20250 individuals processed
# Pop 151  Perfect solution in 390 generations, 58890 individuals processed
# Pop 152  Perfect solution in 508 generations, 77216 individuals processed
# Pop 153  Perfect solution in 1190 generations, 182070 individuals processed
# Pop 154  Perfect solution in 136 generations, 20944 individuals processed
# Pop 155  Perfect solution in 620 generations, 96100 individuals processed
# Pop 156  Perfect solution in 1783 generations, 278148 individuals processed
# Pop 157  Perfect solution in 131 generations, 20567 individuals processed
# Pop 158  Perfect solution in 101 generations, 15958 individuals processed
# Pop 159  Perfect solution in 250 generations, 39750 individuals processed
# Pop 160  Perfect solution in 738 generations, 118080 individuals processed
# Pop 161  Perfect solution in 87 generations, 14007 individuals processed
# Pop 162  Perfect solution in 406 generations, 65772 individuals processed
# Pop 163  Perfect solution in 736 generations, 119968 individuals processed
# Pop 164  Perfect solution in 262 generations, 42968 individuals processed
# Pop 165  Perfect solution in 216 generations, 35640 individuals processed
# Pop 166  Perfect solution in 273 generations, 45318 individuals processed
# Pop 167  Perfect solution in 137 generations, 22879 individuals processed
# Pop 168  Perfect solution in 242 generations, 40656 individuals processed
# Pop 169  Perfect solution in 234 generations, 39546 individuals processed
# Pop 170  Perfect solution in 123 generations, 20910 individuals processed
# Pop 171  Perfect solution in 835 generations, 142785 individuals processed
# Pop 172  Perfect solution in 162 generations, 27864 individuals processed
# Pop 173  Perfect solution in 1044 generations, 180612 individuals processed
# Pop 174  Perfect solution in 241 generations, 41934 individuals processed
# Pop 175  Perfect solution in 451 generations, 78925 individuals processed
# Pop 176  Perfect solution in 186 generations, 32736 individuals processed
# Pop 177  Perfect solution in 423 generations, 74871 individuals processed
# Pop 178  Perfect solution in 943 generations, 167854 individuals processed
# Pop 179  Perfect solution in 455 generations, 81445 individuals processed
# Pop 180  Perfect solution in 289 generations, 52020 individuals processed
# Pop 181  Perfect solution in 315 generations, 57015 individuals processed
# Pop 182  Perfect solution in 220 generations, 40040 individuals processed
# Pop 183  Perfect solution in 112 generations, 20496 individuals processed
# Pop 184  Perfect solution in 118 generations, 21712 individuals processed
# Pop 185  Perfect solution in 261 generations, 48285 individuals processed
# Pop 186  Perfect solution in 218 generations, 40548 individuals processed
# Pop 187  Perfect solution in 125 generations, 23375 individuals processed
# Pop 188  Perfect solution in 98 generations, 18424 individuals processed
# Pop 189  Perfect solution in 111 generations, 20979 individuals processed
# Pop 190  Perfect solution in 640 generations, 121600 individuals processed
# Pop 191  Perfect solution in 81 generations, 15471 individuals processed
# Pop 192  Perfect solution in 914 generations, 175488 individuals processed
# Pop 193  Perfect solution in 146 generations, 28178 individuals processed
# Pop 194  Perfect solution in 139 generations, 26966 individuals processed
# Pop 195  Perfect solution in 86 generations, 16770 individuals processed
# Pop 196  Perfect solution in 155 generations, 30380 individuals processed
# Pop 197  Perfect solution in 144 generations, 28368 individuals processed
# Pop 198  Perfect solution in 124 generations, 24552 individuals processed
# Pop 199  Perfect solution in 69 generations, 13731 individuals processed
# Pop 200  Perfect solution in 141 generations, 28200 individuals processed
#
#  Final configuration:
# Smallest population size : 121
# smallest Generation size: 71
# Individuals processed = 8591

# %% [markdown]
# scroll down the result to see the final result:
# using roulette wheel selection, the smallest population size that found a perfect solution was 121, with 71 generations needed, resulting in 8591 individuals processed. The population range was from 50-200 and the max number of generation was 5000

# %% [markdown]
# Now that we're done, let's print out some statistics. Generally we record (at least) the max and average over time.

# %%
# Genetic Algorithm is done - plot statistics:
#sns.set_style("whitegrid")
plt.plot(result[3], color='red')
plt.plot(result[4], color='green')
plt.xlabel('Generation')
plt.ylabel('Max / Average Fitness')
plt.title('Max and Average Fitness over Generations')
plt.show()
